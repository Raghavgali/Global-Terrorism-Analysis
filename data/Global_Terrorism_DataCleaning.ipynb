# %% [markdown]
# # Questions I can ask from this Data
# 1. Which country has the highest number of Terror Attacks?
# 2. What is the most used weapon?
# 3. Which target groups were most attacked?
# 4. Which perpertrator groups have the highest number of attacks?
# 5. Frequency of Terrorist incidents over years
# 6. Distribution of Casualities
# 7. What are the most common types of Terrorist attacks?

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import chardet

# %%
with open('globalterrorismdb_0718dist.csv', 'rb') as f:
    encoding = chardet.detect(f.read())['encoding']

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding=encoding)
# Out:
# /var/folders/nq/j6_w6klj0yd9h2kwhxzcbyhm0000gn/T/ipykernel_75203/43825309.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding=encoding)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Selecting Relevant Columns for the visualizations

# %%
sub = ['eventid', 'iyear','imonth', 'iday', 'country_txt', 'city', 'latitude', 'longitude', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt', 'gname', 'weaptype1_txt', 'weapsubtype1_txt']
df2 = df[sub]

# %%
df2.head()
# Out:
#         eventid  iyear  imonth  iday         country_txt           city  \
# 0  197000000001   1970       7     2  Dominican Republic  Santo Domingo
# 1  197000000002   1970       0     0              Mexico    Mexico city
# 2  197001000001   1970       1     0         Philippines        Unknown
# 3  197001000002   1970       1     0              Greece         Athens
# 4  197001000003   1970       1     0               Japan        Fukouka
#
#     latitude   longitude                 attacktype1_txt  \
# 0  18.456792  -69.951164                   Assassination
# 1  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2  15.478598  120.599741                   Assassination
# 3  37.997490   23.762728               Bombing/Explosion
# 4  33.580412  130.396361  Facility/Infrastructure Attack
#
#                  targtype1_txt  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# ...

# %%
df2.isnull().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# country_txt             0
# city                  435
# latitude             4556
# longitude            4557
# attacktype1_txt         0
# targtype1_txt           0
# targsubtype1_txt    10373
# gname                   0
# weaptype1_txt           0
# weapsubtype1_txt    20768
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# eventid             0
# iyear               0
# imonth              0
# iday                0
# country_txt         0
# city                0
# latitude            0
# longitude           0
# attacktype1_txt     0
# targtype1_txt       0
# targsubtype1_txt    0
# gname               0
# weaptype1_txt       0
# weapsubtype1_txt    0
# dtype: int64

# %%
df2.head()
# Out:
#         eventid  iyear  imonth  iday    country_txt        city   latitude  \
# 3  197001000002   1970       1     0         Greece      Athens  37.997490
# 5  197001010002   1970       1     1  United States       Cairo  37.005105
# 6  197001020001   1970       1     2        Uruguay  Montevideo -34.891151
# 7  197001020002   1970       1     2  United States     Oakland  37.791927
# 8  197001020003   1970       1     2  United States     Madison  43.076592
#
#     longitude                 attacktype1_txt            targtype1_txt  \
# 3   23.762728               Bombing/Explosion  Government (Diplomatic)
# 5  -89.176269                   Armed Assault                   Police
# 6  -56.187214                   Assassination                   Police
# 7 -122.225906               Bombing/Explosion                Utilities
# 8  -89.412488  Facility/Infrastructure Attack                 Military
#
#                                   targsubtype1_txt                gname  \
# ...

# %%
df2.shape
# Out:
# (147803, 14)

# %%
df2.head(100)
# Out:
#           eventid  iyear  imonth  iday    country_txt        city   latitude  \
# 3    197001000002   1970       1     0         Greece      Athens  37.997490
# 5    197001010002   1970       1     1  United States       Cairo  37.005105
# 6    197001020001   1970       1     2        Uruguay  Montevideo -34.891151
# 7    197001020002   1970       1     2  United States     Oakland  37.791927
# 8    197001020003   1970       1     2  United States     Madison  43.076592
# ..            ...    ...     ...   ...            ...         ...        ...
# 107  197003040002   1970       3     4  United States    Martinez  38.019304
# 108  197003040003   1970       3     4  United States      Denver  39.758968
# 109  197003050001   1970       3     5  United States     Seattle  47.610786
# 110  197003050002   1970       3     5  United States      Denver  39.758968
# 111  197003050003   1970       3     5  United States    San Juan  18.386932
#
# ...

# %%
df2.count()
# Out:
# eventid             147803
# iyear               147803
# imonth              147803
# iday                147803
# country_txt         147803
# city                147803
# latitude            147803
# longitude           147803
# attacktype1_txt     147803
# targtype1_txt       147803
# targsubtype1_txt    147803
# gname               147803
# weaptype1_txt       147803
# weapsubtype1_txt    147803
# dtype: int64

# %%
df2.dtypes
# Out:
# eventid               int64
# iyear                 int64
# imonth                int64
# iday                  int64
# country_txt          object
# city                 object
# latitude            float64
# longitude           float64
# attacktype1_txt      object
# targtype1_txt        object
# targsubtype1_txt     object
# gname                object
# weaptype1_txt        object
# weapsubtype1_txt     object
# dtype: object

# %%
df2.head()
# Out:
#         eventid  iyear  imonth  iday    country_txt        city   latitude  \
# 3  197001000002   1970       1     0         Greece      Athens  37.997490
# 5  197001010002   1970       1     1  United States       Cairo  37.005105
# 6  197001020001   1970       1     2        Uruguay  Montevideo -34.891151
# 7  197001020002   1970       1     2  United States     Oakland  37.791927
# 8  197001020003   1970       1     2  United States     Madison  43.076592
#
#     longitude                 attacktype1_txt            targtype1_txt  \
# 3   23.762728               Bombing/Explosion  Government (Diplomatic)
# 5  -89.176269                   Armed Assault                   Police
# 6  -56.187214                   Assassination                   Police
# 7 -122.225906               Bombing/Explosion                Utilities
# 8  -89.412488  Facility/Infrastructure Attack                 Military
#
#                                   targsubtype1_txt                gname  \
# ...

# %% [markdown]
# ### Renaming Columns

# %%
df2.rename(columns={'iyear': 'year', 'imonth':'month', 'iday':'day', 'country_txt': 'country', 'attacktype1_txt':'attacktype', 'targtype1_txt': 'targtype', 'targsubtype1_txt': 'targsubtype', 'gname': 'pgroup', 'weaptype1_txt': 'weaptype', 'weapsubtype1_txt': 'weapsubtype'}, inplace=True)

# %%
df2.head()
# Out:
#         eventid  year  month  day        country        city   latitude  \
# 3  197001000002  1970      1    0         Greece      Athens  37.997490
# 5  197001010002  1970      1    1  United States       Cairo  37.005105
# 6  197001020001  1970      1    2        Uruguay  Montevideo -34.891151
# 7  197001020002  1970      1    2  United States     Oakland  37.791927
# 8  197001020003  1970      1    2  United States     Madison  43.076592
#
#     longitude                      attacktype                 targtype  \
# 3   23.762728               Bombing/Explosion  Government (Diplomatic)
# 5  -89.176269                   Armed Assault                   Police
# 6  -56.187214                   Assassination                   Police
# 7 -122.225906               Bombing/Explosion                Utilities
# 8  -89.412488  Facility/Infrastructure Attack                 Military
#
#                                        targsubtype               pgroup  \
# ...

# %% [markdown]
# ### For some of the events the date of the actual event is unknown therefore just going ahead with month and the year column

# %%
df2 = df2.drop(df2[df2['month']==0].index)
df2 = df2.drop(df2[df2['day']==0].index)

# %%
position = 4
new_column = df2['year'].astype(str) + '/' + df2['month'].astype(str) + '/' + df2['day'].astype(str)
df2.insert(position, 'date', new_column)

# %%
df2.head()
# Out:
#         eventid  year  month  day      date        country        city  \
# 5  197001010002  1970      1    1  1970/1/1  United States       Cairo
# 6  197001020001  1970      1    2  1970/1/2        Uruguay  Montevideo
# 7  197001020002  1970      1    2  1970/1/2  United States     Oakland
# 8  197001020003  1970      1    2  1970/1/2  United States     Madison
# 9  197001030001  1970      1    3  1970/1/3  United States     Madison
#
#     latitude   longitude                      attacktype  \
# 5  37.005105  -89.176269                   Armed Assault
# 6 -34.891151  -56.187214                   Assassination
# 7  37.791927 -122.225906               Bombing/Explosion
# 8  43.076592  -89.412488  Facility/Infrastructure Attack
# 9  43.072950  -89.386694  Facility/Infrastructure Attack
#
#                targtype                                      targsubtype  \
# 5                Police  Police Building (headquarters, station, school)
# ...

# %%
df2['date'] = pd.to_datetime(df2['date'])

# %%
df2.columns
# Out:
# Index(['eventid', 'year', 'month', 'day', 'date', 'country', 'city',
#        'latitude', 'longitude', 'attacktype', 'targtype', 'targsubtype',
#        'pgroup', 'weaptype', 'weapsubtype'],
#       dtype='object')

# %%
df2.to_csv('Global Terrorism Cleaned.csv', index=False)

# %%
df2.groupby(['country'])['eventid'].size()
# Out:
# country
# Afghanistan    10010
# Albania           68
# Algeria         2163
# Angola           386
# Argentina        613
#                ...
# Yemen           2559
# Yugoslavia       186
# Zaire             27
# Zambia            51
# Zimbabwe          75
# Name: eventid, Length: 201, dtype: int64

# %%
df2
# Out:
#              eventid  year  month  day       date        country  \
# 5       197001010002  1970      1    1 1970-01-01  United States
# 6       197001020001  1970      1    2 1970-01-02        Uruguay
# 7       197001020002  1970      1    2 1970-01-02  United States
# 8       197001020003  1970      1    2 1970-01-02  United States
# 9       197001030001  1970      1    3 1970-01-03  United States
# ...              ...   ...    ...  ...        ...            ...
# 181685  201712310020  2017     12   31 2017-12-31    Afghanistan
# 181686  201712310022  2017     12   31 2017-12-31        Somalia
# 181687  201712310029  2017     12   31 2017-12-31          Syria
# 181688  201712310030  2017     12   31 2017-12-31    Philippines
# 181689  201712310031  2017     12   31 2017-12-31          India
#
#                  city   latitude   longitude                      attacktype  \
# 5               Cairo  37.005105  -89.176269                   Armed Assault
# ...

# %%
df2.value_counts('weaptype')
# Out:
# weaptype
# Explosives    83155
# Firearms      54713
# Incendiary     5923
# Melee          3377
# Chemical        139
# Other             1
# Name: count, dtype: int64

# %%
df2.value_counts('weapsubtype')
# Out:
# weapsubtype
# Unknown Explosive Type                       40160
# Unknown Gun Type                             31655
# Automatic or Semi-Automatic Rifle            15618
# Projectile (rockets, mortars, RPGs, etc.)     9433
# Vehicle                                       8930
# Handgun                                       6226
# Other Explosive Type                          6152
# Grenade                                       4896
# Arson/Fire                                    3942
# Landmine                                      3626
# Suicide (carried bodily by human being)       2878
# Remote Trigger                                2459
# Knife or Other Sharp Object                   2405
# Sticky Bomb                                   1550
# Molotov Cocktail/Petrol Bomb                  1190
# Dynamite/TNT                                  1159
# Rifle/Shotgun (non-automatic)                 1134
# Gasoline or Alcohol                            791
# ...
